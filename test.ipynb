# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Shramanth P Acharya\Unified Mentor Private\hhs_analytics_for_unaccompanied children\data\HHS_Unaccompanied_Alien_Children_Program.csv")
print(df.columns)
# Out:
# Index(['Date', 'Children apprehended and placed in CBP custody*',
#        'Children in CBP custody', 'Children transferred out of CBP custody',
#        'Children in HHS Care', 'Children discharged from HHS Care'],
#       dtype='object')
